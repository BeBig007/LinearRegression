# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "data/data.csv"
data= pd.read_csv(path)

data.head()
# Out:
#        km  price
# 0  240000   3650
# 1  139800   3800
# 2  150500   4400
# 3  185530   4450
# 4  176000   5250

# %%
plt.figure()
plt.scatter(data['price'], data['km'])
plt.xlabel('price')
plt.ylabel('km')
plt.show()
